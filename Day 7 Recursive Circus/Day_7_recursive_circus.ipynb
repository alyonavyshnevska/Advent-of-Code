# %%
d = {}
with open('input.txt', 'r') as f:
    for line in f:
        if '->' in line.split():
            k,v = line.split('->')
            k = k.strip()
            v = v.strip()
            name, weight = k.split()
            v_set = tuple(v.split())
            d[v_set] = name
        #else:
            #d[line.strip()] = []

for key in d.keys():
    if 'vpbdpfm' in key:
        new_key = d[key]
        print(d[key])
        
for key in d.keys():
    if new_key in key:
        new_key = d[key]
        print(d[key])
        
for key in d.keys():
    if new_key in key:
        new_key = d[key]
        print(d[key])
        
for key in d.keys():
    if new_key in key:
        new_key = d[key]
        print(d[key])
        
for key in d.keys():
    if new_key in key:
        new_key = d[key]
        print(d[key])
        
for key,value in d.items():
    print('', key, ':            ', value)
# Out:
#  ('ndegtj,', 'wnwxs') :             vpbdpfm
#  ('vliyv,', 'rfxmk,', 'nulxd,', 'tckql') :             dosteiu
#  ('wuttw,', 'nckca') :             leqnli
#  ('zbtmpkc,', 'lleaucw,', 'zxvjkqv,', 'tqjyoj') :             cgztcyz
#  ('zpbbgqh,', 'menyi,', 'ksasli,', 'uahdbi,', 'ccfiz,', 'kdwmlx') :             vsjhe
#  ('usvzfi,', 'uxxtnll,', 'phrkfo,', 'vntjo') :             ensyb
#  ('rgylin,', 'yrmfcs') :             apjsu
#  ('jdntuc,', 'htaxf,', 'edpqtnn') :             wjdkcjo
#  ('lqjnh,', 'xkfwmh') :             bejkc
#  ('akxrge,', 'qgqrmeu,', 'nsnhdll,', 'ydyvay') :             haeyms
#  ('dvasofv,', 'mxdxz') :             otqufza
#  ('mivrqpc,', 'hdqgdm,', 'muulq,', 'tveyfha') :             wiihwvv
#  ('yjpzyzx,', 'vdnvw,', 'nsbyncu,', 'wpafb') :             shkfwm
#  ('kxkwc,', 'mpwnd') :             xaaqdv
#  ('gxmqlu,', 'sfteyu') :             lfzvi
#  ('umiohmp,', 'zeauj') :             wxvsp
#  ('dletgs,', 'bcgqdc') :             opghigg
# ...

# %%
d = {}
with open('input.txt', 'r') as f:
    for line in f:
        split_line = line.split()
        for position in range(3, len(split_line)):
            d[split_line[position].strip(',')] = split_line[0].strip(',')
            
print(d)
# Out:
# {'ndegtj': 'vpbdpfm', 'wnwxs': 'vpbdpfm', 'vliyv': 'dosteiu', 'rfxmk': 'dosteiu', 'nulxd': 'dosteiu', 'tckql': 'dosteiu', 'wuttw': 'leqnli', 'nckca': 'leqnli', 'zbtmpkc': 'cgztcyz', 'lleaucw': 'cgztcyz', 'zxvjkqv': 'cgztcyz', 'tqjyoj': 'cgztcyz', 'zpbbgqh': 'vsjhe', 'menyi': 'vsjhe', 'ksasli': 'vsjhe', 'uahdbi': 'vsjhe', 'ccfiz': 'vsjhe', 'kdwmlx': 'vsjhe', 'usvzfi': 'ensyb', 'uxxtnll': 'ensyb', 'phrkfo': 'ensyb', 'vntjo': 'ensyb', 'rgylin': 'apjsu', 'yrmfcs': 'apjsu', 'jdntuc': 'wjdkcjo', 'htaxf': 'wjdkcjo', 'edpqtnn': 'wjdkcjo', 'lqjnh': 'bejkc', 'xkfwmh': 'bejkc', 'akxrge': 'haeyms', 'qgqrmeu': 'haeyms', 'nsnhdll': 'haeyms', 'ydyvay': 'haeyms', 'dvasofv': 'otqufza', 'mxdxz': 'otqufza', 'mivrqpc': 'wiihwvv', 'hdqgdm': 'wiihwvv', 'muulq': 'wiihwvv', 'tveyfha': 'wiihwvv', 'yjpzyzx': 'shkfwm', 'vdnvw': 'shkfwm', 'nsbyncu': 'shkfwm', 'wpafb': 'shkfwm', 'kxkwc': 'xaaqdv', 'mpwnd': 'xaaqdv', 'gxmqlu': 'lfzvi', 'sfteyu': 'lfzvi', 'umiohmp': 'wxvsp', 'zeauj': 'wxvsp', 'dletgs': 'opghigg', 
# ...

# %%
def find_parent(child):
    if child not in d:
        return child
    else:
        return find_parent(d[child])

# %%
for key in d:
    print(find_parent(key))
    break
# Out:
# azqje

# %% [markdown]
# # part two:

# %%
#look-up table
look_up = {}
tree = {}
with open('input.txt', 'r') as f:
    for line in f:
        line_split = line.split()
        look_up[line_split[0]] = int(line_split[1].strip('()'))
        
        if '->' in line:
            for position in range(3, len(line_split)):
                #d[line_split[position].strip(',')] = line_split[0].strip(',')
                tree[line_split[0].strip(',')] = line_split[3:len(line_split)]
        
print(tree)
# Out:
# {'vpbdpfm': ['ndegtj,', 'wnwxs'], 'dosteiu': ['vliyv,', 'rfxmk,', 'nulxd,', 'tckql'], 'leqnli': ['wuttw,', 'nckca'], 'cgztcyz': ['zbtmpkc,', 'lleaucw,', 'zxvjkqv,', 'tqjyoj'], 'vsjhe': ['zpbbgqh,', 'menyi,', 'ksasli,', 'uahdbi,', 'ccfiz,', 'kdwmlx'], 'ensyb': ['usvzfi,', 'uxxtnll,', 'phrkfo,', 'vntjo'], 'apjsu': ['rgylin,', 'yrmfcs'], 'wjdkcjo': ['jdntuc,', 'htaxf,', 'edpqtnn'], 'bejkc': ['lqjnh,', 'xkfwmh'], 'haeyms': ['akxrge,', 'qgqrmeu,', 'nsnhdll,', 'ydyvay'], 'otqufza': ['dvasofv,', 'mxdxz'], 'wiihwvv': ['mivrqpc,', 'hdqgdm,', 'muulq,', 'tveyfha'], 'shkfwm': ['yjpzyzx,', 'vdnvw,', 'nsbyncu,', 'wpafb'], 'xaaqdv': ['kxkwc,', 'mpwnd'], 'lfzvi': ['gxmqlu,', 'sfteyu'], 'wxvsp': ['umiohmp,', 'zeauj'], 'opghigg': ['dletgs,', 'bcgqdc'], 'kabjov': ['eulcspz,', 'nxttce'], 'nfeok': ['apqan,', 'ywtywz,', 'inoyp'], 'ccmfbok': ['jbopt,', 'cteuws,', 'rrsxb,', 'atfjks'], 'qizkjh': ['mxsacj,', 'liiwwfa'], 'ksnnnc': ['iuuzow,', 'eiyvtz,', 'dlxcy,', 'ltfbsgc'], 'mhbiyxk': ['ehpfjr,', 'zqgeod,', '
# ...
